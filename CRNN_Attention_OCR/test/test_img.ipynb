# %%
import os
import cv2
import matplotlib.pyplot as plt
import random

# %%
list_img = os.listdir("../Synthetic Chinese String Dataset_2/images")
print len(list_img)
# Out:
# 3644007

# %%
rand_numb = random.randint(0,len(list_img))
print rand_numb
img = plt.imread("../Synthetic Chinese String Dataset_2/images/"+list_img[rand_numb])
plt.imshow(img)
# Out:
# 1392609

# %%
import numpy as np
val_img = cv2.imread("10.png",0)

val_img = cv2.resize(val_img,(240,32))

val_img = val_img.swapaxes(0, 1)
plt.imshow(val_img)
# val_img = np.zeros(( 512,val_img.shape[0], val_img.shape[1], 1))+np.array(val_img[ np.newaxis,:, :, np.newaxis])
